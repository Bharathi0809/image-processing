# %%
import os
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from skimage.io import imread,imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
naz=os.listdir("C:/naz/nazriya")

# %%
siva=os.listdir("C:/siva/sivaangi")

# %%
jeeva=os.listdir("C:/jeeva/ jeeva")

# %%
limit = 10
naz_images = [None]*limit
j=0

for i in naz:
    if(j<limit):
        naz_images[j] = imread("C:/naz/nazriya/"+i)
        j+=1
    else:
        break

# %%
limit = 10
siva_images = [None]*limit
j=0

for i in siva:
    if(j<limit):
        siva_images[j] = imread("C:/siva/sivaangi/"+i)
        j+=1
    else:
        break

# %%
limit = 10
jeeva_images = [None]*limit
j=0

for i in jeeva:
    if(j<limit):
        jeeva_images[j] = imread("C:/jeeva/ jeeva/"+i)
        j+=1
    else:
        break

# %%
imshow(naz_images[5])

# %%
imshow(siva_images[5])

# %%
imshow(jeeva_images[5])

# %%
naz_gray = [None]*limit
j=0
for i in naz:
    if(j<limit):
        naz_gray[j]=rgb2gray(naz_images[j])
        j+=1
    else:
        break

# %%
siva_gray = [None]*limit
j=0
for i in siva:
    if(j<limit):
        siva_gray[j]=rgb2gray(siva_images[j])
        j+=1
    else:
        break

# %%
jeeva_gray = [None]*limit
j=0
for i in jeeva:
    if(j<limit):
        jeeva_gray[j]=rgb2gray(jeeva_images[j])
        j+=1
    else:
        break

# %%
imshow(naz_gray[4])

# %%
imshow(siva_gray[4])

# %%
imshow(jeeva_gray[4])

# %%
naz_gray[4].shape
# Out:
# (928, 1600)

# %%
siva_gray[4].shape
# Out:
# (822, 1080)

# %%
jeeva_gray[4].shape
# Out:
# (1542, 1024)

# %%
for j in range(10):
    a=naz_gray[j]
    naz_gray[j]=resize(a,(512,512))

# %%
for j in range(10):
    a=siva_gray[j]
    siva_gray[j]=resize(a,(512,512))

# %%
for j in range(10):
    a=jeeva_gray[j]
    jeeva_gray[j]=resize(a,(512,512))

# %%
imshow(naz_gray[9])

# %%
imshow(siva_gray[9])

# %%
imshow(jeeva_gray[9])

# %%
len_of_images_naz=len(naz_gray)
len_of_images_naz
# Out:
# 10

# %%
len_of_images_siva=len(siva_gray)
len_of_images_siva
# Out:
# 10

# %%
len_of_images_jeeva=len(jeeva_gray)
len_of_images_jeeva
# Out:
# 10

# %%
image_size_naz=naz_gray[1].shape

# %%
image_size_siva=siva_gray[1].shape

# %%
image_size_jeeva=jeeva_gray[1].shape

# %%
flatten_size_naz= image_size_naz[0]*image_size_naz[1]
flatten_size_naz
# Out:
# 262144

# %%
flatten_size_siva= image_size_siva[0]*image_size_siva[1]
flatten_size_siva
# Out:
# 262144

# %%
flatten_size_jeeva= image_size_jeeva[0]*image_size_jeeva[1]
flatten_size_jeeva
# Out:
# 262144

# %%
for i in range(len_of_images_naz):
    naz_gray[i]=np.ndarray.flatten(naz_gray[i].reshape(flatten_size_naz,1))

# %%
for i in range(len_of_images_siva):
    siva_gray[i]=np.ndarray.flatten(siva_gray[i].reshape(flatten_size_siva,1))

# %%
naz_gray=np.dstack(naz_gray)

# %%
naz_gray.shape
# Out:
# (1, 262144, 10)

# %%
siva_gray=np.dstack(siva_gray)
siva_gray.shape
# Out:
# (1, 262144, 10)

# %%
jeeva_gray=np.dstack(jeeva_gray)
jeeva_gray.shape
# Out:
# (512, 512, 10)

# %%
naz_gray=np.rollaxis(naz_gray,axis=2,start=0)
naz_gray.shape
# Out:
# (10, 1, 262144)

# %%
siva_gray=np.rollaxis(siva_gray,axis=2,start=0)
siva_gray.shape
# Out:
# (10, 1, 262144)

# %%
jeeva_gray=np.rollaxis(jeeva_gray,axis=2,start=0)
jeeva_gray.shape
# Out:
# (10, 512, 512)

# %%
naz_gray=naz_gray.reshape(len_of_images_naz,flatten_size_naz)
naz_gray.shape
# Out:
# (10, 262144)

# %%
siva_gray=siva_gray.reshape(len_of_images_siva,flatten_size_siva)
siva_gray.shape
# Out:
# (10, 262144)

# %%
jeeva_gray=jeeva_gray.reshape(len_of_images_jeeva,flatten_size_jeeva)
jeeva_gray.shape
# Out:
# (10, 262144)

# %%
naz_data=pd.DataFrame(naz_gray)

# %%
naz_gray
# Out:
# array([[0.16838909, 0.16838909, 0.16838909, ..., 0.19719051, 0.20640118,
#         0.19502103],
#        [0.45965275, 0.32625823, 0.29362911, ..., 0.1049785 , 0.10646766,
#         0.11207159],
#        [0.5603534 , 0.56229201, 0.56517916, ..., 0.54839903, 0.5513325 ,
#         0.2979335 ],
#        ...,
#        [0.97647059, 0.97647059, 0.97647059, ..., 0.72115378, 0.71403808,
#         0.71434661],
#        [0.87018824, 0.87018824, 0.87018824, ..., 0.05184784, 0.0567498 ,
#         0.06165176],
#        [0.76307956, 0.76485589, 0.76674576, ..., 0.40304005, 0.39547348,
#         0.40082606]])

# %%
siva_data=pd.DataFrame(siva_gray)
siva_gray
# Out:
# array([[0.24623327, 0.27224718, 0.25835922, ..., 0.22216665, 0.21716801,
#         0.19490835],
#        [0.58816   , 0.58816   , 0.58816   , ..., 0.78823529, 0.78823529,
#         0.78823529],
#        [0.16498204, 0.2450308 , 0.30481201, ..., 0.34655309, 0.8140695 ,
#         0.76346516],
#        ...,
#        [0.38372952, 0.35350665, 0.33365595, ..., 0.18515831, 0.18538431,
#         0.18538431],
#        [1.        , 1.        , 1.        , ..., 0.72929422, 0.7275872 ,
#         0.73132086],
#        [0.7636796 , 0.76845135, 0.77377896, ..., 0.5466168 , 0.54236588,
#         0.54586236]])

# %%
jeeva_data=pd.DataFrame(jeeva_gray)
jeeva_gray
# Out:
# array([[0.57736235, 0.57736235, 0.57736235, ..., 0.81413492, 0.80410169,
#         0.8331201 ],
#        [0.24355892, 0.24093262, 0.23994289, ..., 0.65215352, 0.64300327,
#         0.62809992],
#        [0.73290804, 0.72991841, 0.72960231, ..., 0.60560132, 0.61191038,
#         0.59951509],
#        ...,
#        [0.68766235, 0.68766235, 0.68766235, ..., 0.3238663 , 0.31043199,
#         0.31676779],
#        [0.34957364, 0.35312195, 0.35318853, ..., 0.62165372, 0.6204321 ,
#         0.61796128],
#        [0.96522667, 0.96522667, 0.96522667, ..., 0.99607843, 0.99607843,
#         0.99607843]])

# %%
naz_data["label"]="naz"
naz_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.168389  0.168389  0.168389  0.168453  0.169522  0.169586  0.169586
# 1  0.459653  0.326258  0.293629  0.279289  0.248852  0.232786  0.210717
# 2  0.560353  0.562292  0.565179  0.567903  0.567237  0.560775  0.555443
# 3  0.771659  0.774937  0.774937  0.778858  0.778858  0.782014  0.783301
# 4  0.988235  0.988235  0.988235  0.988235  0.988235  0.988235  0.988235
# 5  0.255106  0.254921  0.254922  0.256018  0.257040  0.259999  0.262189
# 6  0.431625  0.426713  0.422446  0.419833  0.415179  0.407458  0.405660
# 7  0.976471  0.976471  0.976471  0.976471  0.976471  0.976471  0.976471
# 8  0.870188  0.870188  0.870188  0.870188  0.870188  0.870188  0.870188
# 9  0.763080  0.764856  0.766746  0.768407  0.767834  0.767388  0.767388
#
#           7         8         9  ...    262135    262136    262137    262138  \
# 0  0
indexed
# Out:
#     index         0         1         2         3         4         5  \
# 0       1  0.243559  0.240933  0.239943  0.250253  0.253967  0.253254
# 1       0  0.577362  0.577362  0.577362  0.577288  0.576038  0.575964
# 2       3  0.690255  0.688959  0.678168  0.622796  0.509942  0.430932
# 3       0  0.168389  0.168389  0.168389  0.168453  0.169522  0.169586
# 4       2  0.164982  0.245031  0.304812  0.173901  0.220915  0.361652
# 5       6  0.360119  0.360119  0.362471  0.364041  0.364041  0.364575
# 6       2  0.732908  0.729918  0.729602  0.734035  0.734832  0.736593
# 7       7  0.687662  0.687662  0.687662  0.687662  0.687662  0.687662
# 8       2  0.560353  0.562292  0.565179  0.567903  0.567237  0.560775
# 9       4  0.847558  0.839560  0.841833  0.843771  0.858638  0.835106
# 10      3  0.327722  0.324510  0.329261  0.337321  0.339758  0.349186
# 11      5  0.255106  0.254921  0.254922  0.256018  0.257040  0.259999
# ...

# %%
hollywood_actors=hollywood_indexed.drop(["index"],axis=1)
hollywood_actors
# Out:
#            0         1         2         3         4         5             6  \
# 0   0.243559  0.240933  0.239943  0.250253  0.253967  0.253254  2.536749e-01
# 1   0.577362  0.577362  0.577362  0.577288  0.576038  0.575964  5.759635e-01
# 2   0.690255  0.688959  0.678168  0.622796  0.509942  0.430932  3.768188e-01
# 3   0.168389  0.168389  0.168389  0.168453  0.169522  0.169586  1.695855e-01
# 4   0.164982  0.245031  0.304812  0.173901  0.220915  0.361652  1.446514e-01
# 5   0.360119  0.360119  0.362471  0.364041  0.364041  0.364575  3.683438e-01
# 6   0.732908  0.729918  0.729602  0.734035  0.734832  0.736593  7.401749e-01
# 7   0.687662  0.687662  0.687662  0.687662  0.687662  0.687662  6.876624e-01
# 8   0.560353  0.562292  0.565179  0.567903  0.567237  0.560775  5.554432e-01
# 9   0.847558  0.839560  0.841833  0.843771  0.858638  0.835106  8.216928e-01
# 10  0.327722  0.324510  0.329261  0.337321  0.339758  0.349186  3.602658e-01
# ...

# %%
x=hollywood_actors.values[:,:-1]

# %%
y=hollywood_actors.values[:,-1]

# %%
x
# Out:
# array([[0.24355892363522036, 0.24093261866200655, 0.23994289052302664,
#         ..., 0.6521535171583759, 0.6430032683844509, 0.6280999229305853],
#        [0.5773623529411765, 0.5773623529411765, 0.5773623529411765, ...,
#         0.8141349185050103, 0.8041016903781062, 0.8331201026260318],
#        [0.6902549409323278, 0.6889593860708584, 0.6781679260219949, ...,
#         0.37251840872182473, 0.2983164755697173, 0.32477284343410295],
#        ...,
#        [0.7716586765212138, 0.7749368627280482, 0.7749368627726404, ...,
#         0.1932918699738038, 0.07603722167179829, 0.08972013893567232],
#        [0.24623327251243754, 0.2722471826732142, 0.2583592205515483, ...,
#         0.22216665069851013, 0.2171680104666543, 0.1949083519542586],
#        [0.003921495356409628, 0.0030883732474634817,
#         9.224355339244927e-05, ..., 0.0004068951786958963,
#         1.444715977270765e-06, 1.1316031066186618e-12]], dtype=object)

# %%
y
# Out:
# array(['jeeva', 'jeeva', 'siva', 'naz', 'siva', 'jeeva', 'jeeva', 'jeeva',
#        'naz', 'jeeva', 'jeeva', 'naz', 'siva', 'siva', 'siva', 'naz',
#        'naz', 'siva', 'siva', 'siva', 'jeeva', 'jeeva', 'naz', 'naz',
#        'naz', 'jeeva', 'naz', 'naz', 'siva', 'siva'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn import svm

# %%
clf=svm.SVC()
clf.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=clf.predict(x_test)

# %%
y_pred
# Out:
# array(['jeeva', 'naz', 'jeeva', 'jeeva', 'jeeva', 'naz'], dtype=object)

# %%
for i in (np.random.randint(0,6,4)):
  predicted_images=(np.reshape(x_test[i],(512,512)).astype(np.float64))
  plt.title("Predicted label: {0}".format(y_pred[i]))
  plt.imshow(predicted_images,interpolation="nearest",cmap="gray")
  plt.show()

# %%
from sklearn import metrics

# %%
accuracy=metrics.accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.3333333333333333

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[1, 0, 0],
#        [1, 1, 0],
#        [2, 1, 0]], dtype=int64)
